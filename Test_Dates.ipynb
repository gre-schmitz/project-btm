# %%
import pandas as pd

# %%
test_data = pd.read_csv('data/TrackRecord.csv')

# %%
test_data = test_data.drop(columns=['Unnamed: 4', 'Unnamed: 8', 'Unnamed: 9',
       'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
       'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
       'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
       'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
       'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
       'Unnamed: 30'])

# test_data = test_data.sort_values('Release Date')

# Ensure 'Release Date' is in the correct datetime format
test_data['Release Date'] = pd.to_datetime(test_data['Release Date'], format='%d/%m/%Y')

# Filter 'test_data' to include only rows where 'Release Date' is between 2014-05-01 and 2024-01-19
test_data = test_data[(test_data['Release Date'] > '2014-05-01') & (test_data['Release Date'] < '2024-01-19')]

# %%
test_data = test_data.sort_values('Release Date')

# %%
test_data
# Out:
#    Quarter being forecasted  \
# 38                   Jun-14
# 37                   Sep-14
# 36                   Dec-14
# 35                   Mar-15
# 34                   Jun-15
# 33                   Sep-15
# 32                   Dec-15
# 31                   Mar-16
# 30                   Jun-16
# 29                   Sep-16
# 28                   Dec-16
# 27                   Mar-17
# 26                   Jun-17
# 25                   Sep-17
# 24                   Dec-17
# 23                   Mar-18
# 22                   Jun-18
# 21                   Sep-18
# 20                   Dec-18
# 19                   Mar-19
# 18                   Jun-19
# 17                   Sep-19
# 16                   Dec-19
# 15                   Mar-20
# 14                   Jun-20
# 13                   Sep-20
# 12                   Dec-20
# 11                   Mar-21
# 10                   Jun-21
# 9                    Sep-21
# 8                    Dec-21
# 7                    Mar-22
# 6                    Jun-22
# 5                    Sep-22
# 4                    Dec-22
# 3                    Mar-23
# 2                    Jun-23
# 1                    Sep-23
#
#     Model Forecast Right Before BEA's Advance Estimate  \
# 38                                               2.67
# 37                                               2.70
# 36                                               3.49
# 35                                               0.10
# 34                                               2.43
# 33                                               1.06
# 32                                               1.02
# 31                                               0.62
# 30                                               1.83
# 29                                               2.10
# 28                                               2.88
# 27                                               0.17
# 26                                               2.82
# 25                                               2.52
# 24                                               3.41
# 23                                               1.98
# 22                                               3.82
# 21                                               3.55
# 20                                               1.85
# 19                                               2.67
# 18                                               1.33
# 17                                               1.68
# 16                                               1.74
# 15                                              -0.97
# 14                                             -32.08
# 13                                              36.97
# 12                                               7.16
# 11                                               7.87
# 10                                               6.43
# 9                                                0.19
# 8                                                6.50
# 7                                                0.37
# 6                                               -1.20
# 5                                                3.09
# 4                                                3.53
# 3                                                1.13
# 2                                                2.41
# 1                                                5.41
#
#     BEA's Advance Estimate Release Date  Error  Absolute Error  Squared Error
# 38                    3.95   2014-07-30    1.3             1.3            1.6
# 37                    3.55   2014-10-30    0.8             0.8            0.7
# 36                    2.64   2015-01-30   -0.9             0.9            0.7
# 35                    0.25   2015-04-29    0.1             0.1            0.0
# 34                    2.32   2015-07-30   -0.1             0.1            0.0
# 33                    1.49   2015-10-29    0.4             0.4            0.2
# 32                    0.69   2016-01-29   -0.3             0.3            0.1
# 31                    0.54   2016-04-28   -0.1             0.1            0.0
# 30                    1.22   2016-07-28   -0.6             0.6            0.4
# 29                    2.90   2016-10-28    0.8             0.8            0.6
# 28                    1.87   2017-01-27   -1.0             1.0            1.0
# 27                    0.69   2017-04-28    0.5             0.5            0.3
# 26                    2.57   2017-07-28   -0.3             0.3            0.1
# 25                    2.99   2017-10-27    0.5             0.5            0.2
# 24                    2.56   2018-01-26   -0.9             0.9            0.7
# 23                    2.32   2018-04-27    0.3             0.3            0.1
# 22                    4.06   2018-07-27    0.2             0.2            0.1
# 21                    3.50   2018-10-26   -0.1             0.1            0.0
# 20                    2.59   2019-02-28    0.7             0.7            0.6
# 19                    3.17   2019-04-26    0.5             0.5            0.3
# 18                    2.06   2019-07-26    0.7             0.7            0.5
# 17                    1.92   2019-10-30    0.2             0.2            0.1
# 16                    2.08   2020-01-30    0.3             0.3            0.1
# 15                   -4.78   2020-04-29   -3.8             3.8           14.5
# 14                  -32.90   2020-07-30   -0.8             0.8            0.7
# 13                   33.08   2020-10-30   -3.9             3.9           15.1
# 12                    4.01   2021-01-28   -3.1             3.1            9.9
# 11                    6.39   2021-04-29   -1.5             1.5            2.2
# 10                    6.50   2021-07-29    0.1             0.1            0.0
# 9                     2.02   2021-10-28    1.8             1.8            3.3
# 8                     6.89   2022-01-27    0.4             0.4            0.2
# 7                    -1.41   2022-04-28   -1.8             1.8            3.2
# 6                    -0.93   2022-07-28    0.3             0.3            0.1
# 5                     2.57   2022-10-27   -0.5             0.5            0.3
# 4                     2.89   2023-01-26   -0.6             0.6            0.4
# 3                     1.06   2023-04-27   -0.1             0.1            0.0
# 2                     2.41   2023-07-27    0.0             0.0            0.0
# 1                     4.88   2023-10-26   -0.5             0.5            0.3

# %%
test_data.to_csv('data/Test_Dates.csv')

# %%
test_dates = ['2024-01-19', '2023-10-26', '2023-07-27', '2023-04-27',
               '2023-01-26', '2022-10-27', '2022-07-28', '2022-04-28',
               '2022-01-27', '2021-10-28', '2021-07-29', '2021-04-29',
               '2021-01-28', '2020-10-30', '2020-07-30', '2020-04-29',
               '2020-01-30', '2019-10-30', '2019-07-26', '2019-04-26',
               '2019-02-28', '2018-10-26', '2018-07-27', '2018-04-27',
               '2018-01-26', '2017-10-27', '2017-07-28', '2017-04-28',
               '2017-01-27', '2016-10-28', '2016-07-28', '2016-04-28',
               '2016-01-29', '2015-10-29', '2015-07-30', '2015-04-29',
               '2015-01-30', '2014-10-30', '2014-07-30', 2014-05-01]
